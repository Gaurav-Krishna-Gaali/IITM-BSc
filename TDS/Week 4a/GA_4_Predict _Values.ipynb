# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import mean_absolute_error
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# p:\iitm-bs\TDS\Week 4a\GA_4_Predict _Values.ipynb Cell 1 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from matplotlib import pyplot as plt
# ----> <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from sklearn.metrics import mean_absolute_error
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> from pandas.plotting import autocorrelation_plot
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> from statsmodels.tsa.arima_model import ARIMA
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data = pd.read_csv('master_currency.csv')
data.head(3)
# Out:
#          Date       EUR       AUD       BGN       BRL       CAD       CHF  \
# 0  18/05/2022  1.052299  0.702494  0.538039  0.202466  0.780153  1.003512
# 1  17/05/2022  1.054074  0.703037  0.538967  0.200321  0.779849  1.008065
# 2  16/05/2022  1.042209  0.692185  0.532879  0.197316  0.773575  0.994530
#
#         CNY       CZK       DKK       GBP       HKD       HRK       ILS  \
# 0  0.148269  0.042695  0.141403  1.242854  0.127411  0.139655  0.298436
# 1  0.148677  0.042655  0.141653  1.248907  0.127393  0.140089  0.297876
# 2  0.147232  0.042177  0.140046  1.225490  0.127390  0.138544  0.293789
#
#         INR
# 0  0.012889
# 1  0.012910
# 2  0.012854

# %% [markdown]
# # New Section

# %%
new_data = data[["AUD" , "CNY"]]
new_data
# Out:
#           AUD       CNY
# 0    0.702494  0.148269
# 1    0.703037  0.148677
# 2    0.692185  0.147232
# 3    0.689275  0.147278
# 4    0.689275  0.147278
# ..        ...       ...
# 361  0.776398  0.155473
# 362  0.776398  0.155473
# 363  0.775494  0.155328
# 364  0.774653  0.155381
# 365  0.780884  0.155693
#
# [366 rows x 2 columns]

# %%
X = np.array( new_data.iloc[:,0] ).reshape(-1,1)
Y = np.array( new_data.iloc[:,1] ).reshape(-1,1)

r = np.corrcoef (new_data.iloc[:,0] , new_data.iloc[:,1]) [0][1]
model = LinearRegression().fit(X , Y)
c = model.intercept_
m = r*(np.std(Y) / np.std(X))
x = np.average(X)

predict_value = m*x + c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# p:\iitm-bs\TDS\Week 4a\GA_4_Predict _Values.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> Y = np.array( new_data.iloc[:,1] ).reshape(-1,1)
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> r = np.corrcoef (new_data.iloc[:,0] , new_data.iloc[:,1]) [0][1]
# ----> <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> model = LinearRegression().fit(X , Y)
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> c = model.intercept_
#       <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> m = r*(np.std(Y) / np.std(X))
#
# NameError: name 'LinearRegression' is not defined

# %%
predict_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# p:\iitm-bs\TDS\Week 4a\GA_4_Predict _Values.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/p%3A/iitm-bs/TDS/Week%204a/GA_4_Predict%20_Values.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> predict_value
#
# NameError: name 'predict_value' is not defined
